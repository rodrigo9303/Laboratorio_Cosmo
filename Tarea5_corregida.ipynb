# %%
import scipy.integrate as inte 
import numpy as np 
import scipy.optimize as op
import math 
import matplotlib.pyplot as plt
import emcee
import corner

# %%
x = np.array([0, 1, 2, 3, 4, 5, 6])
y = np.array([-1, 0.2, 0.9, 2.1, 3.5, 4.2, 5.6])
x_err=np.random.normal(0,0.3,len(x))  #(media,sigma,numero de datos)
y_err=np.random.normal(0,0.4,len(y))
plt.plot(x,y,'o',color='black')
plt.errorbar(x,y,yerr=y_err,xerr=x_err, fmt='o',ecolor='black')
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
def modelo(x,a,b):   #se define una funcion y que depende de las variables x,a,b
    return a*x+b    #se escribe la forma de la funcion

# %%
def lnlike(theta):
    a,b =theta
    lolike=-0.5*(np.sum((y-modelo(x,a,b))**2/y_err**2-np.log(2*np.pi*y_err**2)))
    return lolike

# %%
def lnprior(a,b):
    if ((0. < a <2.5) and (-5. < b < 5.)):
        return 0.
    else:
        return -np.infty
    return

# %%
def lnpro(a,b,x,y,y_err):
    lp=lnprior(a,b)
    if not np.isfinite(lp):
        return -np.inf
    return lp + lnlike(a,b, x, y, y_err)

# %%
a0=0.3
b0=0.1

# %%
nparametros, ncaminadores = 2, 10
pos = [np.random.randn(nparametros) for i in range(ncaminadores)]

# %%
sampler = emcee.EnsembleSampler(ncaminadores, nparametros, lnlike)

# %%
sampler.run_mcmc(pos, 10000)
# Out:
# (array([[ 1.11928572, -0.98631747],
#         [ 1.12581748, -0.97784701],
#         [ 1.1284303 , -0.98304816],
#         [ 1.11018847, -0.98743995],
#         [ 1.11005563, -0.97262421],
#         [ 1.11331175, -0.97598194],
#         [ 1.13392355, -0.97975116],
#         [ 1.10074526, -0.97988085],
#         [ 1.09927555, -0.96291108],
#         [ 1.10322256, -0.98106239]]),
#  array([-29.17943783, -29.08552274, -29.14230957, -29.87821574,
#         -28.95175414, -28.8412203 , -29.68221426, -29.93506026,
#         -29.89422379, -29.77016046]),
#  ('MT19937', array([2034729946, 3511040325, 2682692100, 2446428459, 1853812271,
#           645104449, 2940023806,  425536138,  537571691, 2886663054,
#          3169530763, 4208329953,  637127272, 2116615494, 3950363805,
#          3348427209, 3643495541, 1141595279, 1861068223,   57400517,
#          3504241345, 1242317565, 1510777023, 2444715388, 2654039524,
#           778089216, 1886597934, 3840689402, 1289984622,  455431719,
#          2579089717, 1812171379,  151906364,  974217695, 3765683790,
#          2571758038,  205570444, 3964939325, 1633630247, 1137786364,
#           636060372, 4046207470, 2314922286, 3518993809, 1408507482,
#          1874530136, 2734549155,  285632955, 3377429344, 1430023670,
#          2371100425, 1374912534, 2071646430,  990572693, 3437853153,
#          2344736487, 1340267787, 1409083835, 4072210718, 3380176559,
#          2402444553, 3499764036, 1368092738,  693813168, 3049738018,
#          1414779340, 1042520727, 2817441421, 3719545932,  237203899,
#          1456169062,  927897538,  147106534, 2775858414,  939755604,
#          4120829079, 1089831565, 3742244047,   77056025, 2994451556,
#          1012318041, 2803319703, 2461818310, 3269548903,  623871266,
#           275141796, 1165969083,  344341831, 4161617067, 1659364304,
#            44076258,  253681927, 3757611906, 2995362207, 4153359700,
#          1609081539, 1249288508, 1934846705, 3153913041, 3712372612,
#          1735701587, 1170297690, 2303539036,  694331219,  495888513,
#          4138153380, 2942042244, 2820346808,  208724031, 2837848289,
#          2643270343,  169368072,  341075364, 1165988769,  890254750,
#          1054314432, 2363545923, 1650902682, 2071307506, 2220732416,
#          3508076232, 3909574472,  966408737, 1308171056, 2152410454,
#          3676236358, 1046014256, 2066350932, 1976423078, 3387021280,
#          3520181893,   91319575, 1294963062,  954477144, 3431049960,
#          2742334958,  505954826, 1048655615, 3085309946, 1614730326,
#           638890035,  523116703, 3766183278, 3761464918, 4198023917,
#          4078469580,  160289734, 2446722650,  727468273,  275798394,
#          2582041330, 2966388658, 3301671805, 3794216454, 2660389539,
#           815457278, 2627843207,  321929539, 3273005760, 3726374364,
#          3308696938,   53044734, 2585439775, 2971325706, 3737033435,
#           847000177,  262884078, 2620778713, 3888348715, 3983261268,
#          1244215653, 3925797694, 1237348870,  265917399, 1487246298,
#          3014019134, 1551230808, 3389969972,   61320538,   61462863,
#           987948761, 4135361783, 2990309323,  286533885, 1324381202,
#          1136227578, 2909952288, 3712233729,  883951088,  275365510,
#          1093626157, 2522168384, 1732949620, 1250243397, 1149732114,
#          2233475763, 2241693898, 3374840031, 3028065457, 2154240646,
#            65763866, 4142162184, 1165532240,  454425746, 3149417336,
#          2423194952,  764271695, 1090844708,  303748685,  710532227,
#          3609172517, 3884328352,   31346563, 1748474492, 2848063013,
#           397284849, 2443047078, 2446980147, 4258939432, 2897254096,
#          3868576903, 4274467528, 3408519683, 4085240272, 1759478025,
#           742189927, 1249623952,  679539456, 3236434000, 3457720578,
#          2816858417, 3752455051, 1230109142, 1046472894, 1063370891,
#          2876601629,  477974167, 4282204092, 2280634758,  399436787,
#            80319984, 3833094966, 2510249640, 3588132009, 1044548449,
#          1666387086,  392912504, 2246570085, 3969598315, 3862366781,
#          2733864706, 2072176789, 2951312355, 3287508723, 3022542333,
#          2774915305,  184812850,  356995952, 3632111316, 1634628029,
#          3257858326, 2476237946, 1414532094, 3296165069, 1876665531,
#          1872791831, 2952287384, 3115343288, 1052046590, 2797996496,
#            34507828, 1864945854, 3503141135, 3758193069, 2492866744,
#          4212264050, 1048396884,  974021675, 3396744637, 3876411229,
#          2624120385, 1832828827, 2582162654, 2138240443, 2475336251,
#           100933663, 3333251815, 2416127027, 2787918181,  294614492,
#          2562649394,  742884133, 3939129525, 2023912873, 4208525002,
#           240969263, 3689785496, 4064711595,  465844564, 3663841692,
#           124847715, 1919270250, 2916598883, 2286820096, 3164256635,
#          2331148844, 1360100718, 1358890010, 1563032499, 3574247737,
#          2112921365, 2533194354, 4270946927, 2629973328, 2462217027,
#          2946036484,  177401351, 2461536820, 4289610817,  736380108,
#           178578275, 1070172828,  822486833, 3127282971, 2710008297,
#          3514017966, 2323675951, 4270386801, 3409666573,  667457573,
#          1957538950,  427212936,  912320822, 3701746672, 1906520105,
#          2120255253, 3758802149, 3732429116,  390197006, 1612898921,
#          3612213662,  201422284, 3610817019, 3813379286, 3694362608,
#          1701406181, 2111886228, 4110342341,  837391469], dtype=uint32), 46, 0, 0.0))

# %%
plt.plot(sampler.chain[0,:,0], label='pendiente')
plt.plot(sampler.chain[0,:,1], label='ordenada')
plt.legend()

# %%
plt.plot(sampler.chain[0,:,0], sampler.chain[0,:,1])
plt.plot(sampler.chain[1,:,0], sampler.chain[1,:,1])
plt.plot(sampler.chain[5,:,0], sampler.chain[5,:,1])
plt.plot(sampler.chain[7,:,0], sampler.chain[7,:,1])
plt.plot(sampler.chain[9,:,0], sampler.chain[9,:,1])

# %%
samples = sampler.chain[:, 50:, :].reshape((-1, nparametros))

# %%
fig = corner.corner(samples, labels=["$a$", "$b$"], truths=[1.115, -0.975])
