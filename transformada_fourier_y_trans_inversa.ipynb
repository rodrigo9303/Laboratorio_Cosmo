# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def transformada(x):#x es un arreglo de dimensión 1
    N = x.size
    n = np.arange(N)
    w = n.reshape((N,1))
    exponencial = np.exp(-2j*np.pi*w*n/N)
    result = np.dot(exponencial,x)
    return result

# %%
t = np.linspace(-4*np.pi,4*np.pi,500)
r = np.sin(t)

# %%
plt.plot(t,r)

# %%
F = transformada(r)

# %%
plt.plot(F)
# Out:
# /home/rodrigo/miniconda3/lib/python3.6/site-packages/numpy/core/numeric.py:492: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %%
def transformada_inversa(x):#x es un arreglo de dimensión 1
    N = x.size
    n = np.arange(N)
    w = n.reshape((N,1))
    exponencial = np.exp(2j*np.pi*w*n/N)/N
    result = np.dot(exponencial,x)
    return result

# %%
plt.plot(F)
# Out:
# /home/rodrigo/miniconda3/lib/python3.6/site-packages/numpy/core/numeric.py:492: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %%
I=transformada_inversa(transformada(r))

# %%
plt.plot(I)
# Out:
# /home/rodrigo/miniconda3/lib/python3.6/site-packages/numpy/core/numeric.py:492: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
